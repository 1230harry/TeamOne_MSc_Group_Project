# %%
# !pip install seaborn matplotlib

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-db1f9d1b-db91-4774-9a0c-1f8c69088c68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db1f9d1b-db91-4774-9a0c-1f8c69088c68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# How to import csv file dataset in google colab
df = pd.read_csv('customer_review_30kdata.csv')

# %%
df.shape
# Out:
# (29997, 18)

# %%
df.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  1800878dcfa5255c691f2a87ce8b2869  2020-05-16 17:58:33 +0000
# 1  ac06ca1b77310d539c9a74eed7a8a8e2  2020-04-17 01:05:43 +0000
# 2  9c4b10fff4e5e2cc7e2e1bbed76e2220  2020-06-08 10:35:05 +0000
# 3  b5a5dc8de9fc0468aab961f097b56091  2020-04-13 03:57:29 +0000
# 4  430433b52b882e540c16363d448e012b  2020-05-19 03:52:42 +0000
#
#                                              Pageurl      Website Title  \
# 0   https://www.walmart.com/reviews/product/36907838  walmart.com   NaN
# 1  https://www.walmart.com/reviews/product/708236785  walmart.com   NaN
# 2  https://www.walmart.com/reviews/product/831078728  walmart.com   NaN
# 3   https://www.walmart.com/reviews/product/40712755  walmart.com   NaN
# 4   https://www.walmart.com/reviews/product/46597970  walmart.com   NaN
#
#    Rating                                             Review    Reviewer Name  \
# ...

# %%
#Display the first and last lines of the file in dataset
df
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      1800878dcfa5255c691f2a87ce8b2869  2020-05-16 17:58:33 +0000
# 1      ac06ca1b77310d539c9a74eed7a8a8e2  2020-04-17 01:05:43 +0000
# 2      9c4b10fff4e5e2cc7e2e1bbed76e2220  2020-06-08 10:35:05 +0000
# 3      b5a5dc8de9fc0468aab961f097b56091  2020-04-13 03:57:29 +0000
# 4      430433b52b882e540c16363d448e012b  2020-05-19 03:52:42 +0000
# ...                                 ...                        ...
# 29992  355d86361ed106ae2e3168c75f501f34  2020-06-11 09:59:04 +0000
# 29993  254bff8bf86455ec06dd0e866b05d508  2020-05-16 20:01:46 +0000
# 29994  ed0fc14441b566c17cdf6a7d52ba1959  2020-05-18 00:56:22 +0000
# 29995  5a19ee1daaf4c1b4d9459afaafe61e7e  2020-06-06 08:28:55 +0000
# 29996  9916e6e252183b721902bb1c03a11e4b  2020-04-27 06:40:26 +0000
#
#                                                  Pageurl      Website  \
# 0       https://www.walmart.com/reviews/product/36907838  walmart.com
# ...

# %%
'Statistical summary of dataframe (Df)/ customer'
df.describe().T
# Out:
#                     count         mean          std  min   25%    50%    75%  \
# Rating            29997.0     4.143548     1.374402  1.0   4.0    5.0    5.0
# Review Upvotes    29997.0     1.631663    16.178189  0.0   0.0    0.0    0.0
# Review Downvotes  29997.0     0.480315     5.107171  0.0   0.0    0.0    0.0
# Five Star         29903.0  1120.666956  2648.377865  0.0  38.0  161.0  715.0
# Four Star         29903.0   298.424305   841.838937  0.0   9.0   40.0  154.0
# Three Star        29903.0    83.012039   265.664727  0.0   3.0   13.0   42.0
# Two Star          29903.0    47.123901   145.072437  0.0   2.0    8.0   28.0
# One Star          29903.0    82.270006   201.364864  0.0   5.0   18.0   67.0
#
#                       max
# Rating                5.0
# Review Upvotes     1821.0
# Review Downvotes    584.0
# Five Star         18872.0
# Four Star          6811.0
# Three Star         2490.0
# Two Star           1417.0
# One Star           1714.0

# %%
#let us check the walmart dataset data type for features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29997 entries, 0 to 29996
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Uniq Id               29997 non-null  object
#  1   Crawl Timestamp       29997 non-null  object
#  2   Pageurl               29997 non-null  object
#  3   Website               29997 non-null  object
#  4   Title                 2721 non-null   object
#  5   Rating                29997 non-null  float64
#  6   Review                24617 non-null  object
#  7   Reviewer Name         28389 non-null  object
#  8   Review Upvotes        29997 non-null  int64
#  9   Review Downvotes      29997 non-null  int64
#  10  Verified Purchaser    29997 non-null  object
#  11  Recommended Purchase  29997 non-null  object
#  12  Review Date           29997 non-null  object
#  13  Five Star             29903 non-null  float64
#  14  Four Star             29903 non-null  float64
# ...

# %%
#Customer Feedback chart
plt.hist(df['Rating'], bins=5)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Histogram of Ratings')
plt.show()

# %%
# create scatter plot
plt.scatter(df['Uniq Id'], df['Rating'])
plt.xlabel('Uniq Id')
plt.ylabel('Rating')
plt.title('Scatter plot')
plt.show()

# %%
# Lets check null for dataset
df.isnull().sum()
# Out:
# Uniq Id                     0
# Crawl Timestamp             0
# Pageurl                     0
# Website                     0
# Title                   27276
# Rating                      0
# Review                   5380
# Reviewer Name            1608
# Review Upvotes              0
# Review Downvotes            0
# Verified Purchaser          0
# Recommended Purchase        0
# Review Date                 0
# Five Star                  94
# Four Star                  94
# Three Star                 94
# Two Star                   94
# One Star                   94
# dtype: int64

# %%
# fill null values with mean
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-13-850d14b5c868>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
# Lets check null for dataset
df.isnull().sum()
# Out:
# Uniq Id                     0
# Crawl Timestamp             0
# Pageurl                     0
# Website                     0
# Title                   27276
# Rating                      0
# Review                   5380
# Reviewer Name            1608
# Review Upvotes              0
# Review Downvotes            0
# Verified Purchaser          0
# Recommended Purchase        0
# Five Star                   0
# Four Star                   0
# Three Star                  0
# Two Star                    0
# One Star                    0
# dtype: int64

# %%
import seaborn as sns

# Sort the data by a specific feature, such as rating
df_sorted = df.sort_values(by='Five Star', ascending=False)

# Plot a histogram of a specific feature, such as engine size
plt.hist(df['Rating'], bins=10)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Rating of the Customer')
plt.show()

# %%
numerics = ['int64', 'float64']
newdf = df.select_dtypes(include=numerics)
newdf.hist(figsize=[9,10])
plt.show()

# %%
# create scatter plot
plt.scatter(df['Review Upvotes'], df['Review Downvotes'])
plt.xlabel('Review Downvotes')
plt.ylabel('Review Upvotes')
plt.title('Scatter plot')
plt.show()

# %%
# check for null values after filling
print(df.isnull().sum())
# Out:
# Uniq Id                     0
# Crawl Timestamp             0
# Pageurl                     0
# Website                     0
# Title                   27276
# Rating                      0
# Review                   5380
# Reviewer Name            1608
# Review Upvotes              0
# Review Downvotes            0
# Verified Purchaser          0
# Recommended Purchase        0
# Review Date                 0
# Five Star                  94
# Four Star                  94
# Three Star                 94
# Two Star                   94
# One Star                   94
# dtype: int64

# %%
import seaborn as sns

# Sort the data by a specific feature, such as price
df_sorted = df.sort_values(by='price', ascending=False)

# Plot a histogram of a specific feature, such as engine size
plt.hist(df['engine-size'], bins=10)
plt.xlabel('Engine Size')
plt.ylabel('Count')
plt.title('Distribution of Engine Size')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = 'Rating', y= 'Review Upvotes', data = df)
# Out:
# <Axes: xlabel='Rating', ylabel='Review Upvotes'>

# %%
plt.figure(figsize=(20,8))
df = df.set_index('Review Date')
df.plot(grid=True)
# Out:
# <Axes: xlabel='Review Date'>

# %%
#Scatter plot matrix 

# Create a scatter plot matrix
pd.plotting.scatter_matrix(df, figsize=(16,16))
plt.show()

# %%
#let us check the flare dataset data type for features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29997 entries, 0 to 29996
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Uniq Id               29997 non-null  object
#  1   Crawl Timestamp       29997 non-null  object
#  2   Pageurl               29997 non-null  object
#  3   Website               29997 non-null  object
#  4   Title                 2721 non-null   object
#  5   Rating                29997 non-null  float64
#  6   Review                24617 non-null  object
#  7   Reviewer Name         28389 non-null  object
#  8   Review Upvotes        29997 non-null  int64
#  9   Review Downvotes      29997 non-null  int64
#  10  Verified Purchaser    29997 non-null  object
#  11  Recommended Purchase  29997 non-null  object
#  12  Review Date           29997 non-null  object
#  13  Five Star             29903 non-null  float64
#  14  Four Star             29903 non-null  float64
# ...

# %%
sns.pairplot(df, hue="Rating", diag_kind="hist")

# %%
sns.pairplot(
    df,
    plot_kws=dict(marker="+", linewidth=1),
    diag_kws=dict(fill=False),
)

# %%
sns.pairplot(df, corner=True)
